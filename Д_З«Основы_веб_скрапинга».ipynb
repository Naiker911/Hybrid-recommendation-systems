# %% [markdown]
# <a href="https://colab.research.google.com/github/Naiker911/Hybrid-recommendation-systems/blob/main/%D0%94_%D0%97%C2%AB%D0%9E%D1%81%D0%BD%D0%BE%D0%B2%D1%8B_%D0%B2%D0%B5%D0%B1_%D1%81%D0%BA%D1%80%D0%B0%D0%BF%D0%B8%D0%BD%D0%B3%D0%B0%C2%BB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Вам необходимо написать функцию, которая будет основана на поиске по сайту habr.com. Функция в качестве параметра должна принимать список запросов для поиска (например, ['python', 'анализ данных']) и на основе материалов, попавших в результаты поиска по каждому запросу, возвращать датафрейм вида:
#
# <дата> - <заголовок> - <ссылка на материал>
#
# В рамках задания предполагается работа только с одной (первой) страницей результатов поисковой выдачи для каждого запроса. Материалы в датафрейме не должны дублироваться, если они попадали в результаты поиска для нескольких запросов из списка.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
base_url = 'https://habr.com'

def pars_hab(a):
    resp = requests.get(base_url + '/ru/search/', params={
        'q': a,
        'target_type': 'posts',
        'order': 'relevance'
    })
    return resp

def poisk(rest):
    results = []

    for article_tag in soup.find_all('article'):
        datetime = article_tag.find('time').get('datetime')

        h2_tag = article_tag.find('h2')
        title = h2_tag.get_text()
        link = h2_tag.find('a').get('href')

        rating = article_tag.find('span', class_='tm-votes-meter__value').get_text()

        results.append([datetime, title, link, rating])

    return results

vhod =['Аналитика данных','Python']

rez = []
for i in vhod:
    s = pars_hab(i)
    soup = BeautifulSoup(s.text)
    rez = rez + poisk(soup)

new_tabl = pd.DataFrame(rez, columns=['Date', 'Title', 'Link', 'Rating'])
new_tabl.Link = base_url + new_tabl.Link
new_tabl.Date = pd.to_datetime(new_tabl.Date).dt.date
new_tabl.drop_duplicates(inplace=True)
new_tabl.head(40)
# Out:
#           Date                                              Title  \
# 0   2021-12-02  Онлайн-чемпионат SIBUR Challenge 2021 для анал...
# 1   2022-02-26                            Школа аналитиков данных
# 2   2015-08-26  Новая бесплатная библиотека для аналитики данн...
# 3   2022-03-05              МТС запускает Школу аналитиков данных
# 4   2014-09-25  «Всезнайки» от бизнеса – как большие данные ме...
# 5   2021-02-04             Будни аналитиков в «М.Видео—Эльдорадо»
# 6   2020-07-10  Бесплатная Академия Аналитиков Авито для начин...
# 7   2021-12-07  Как работать с HR-данными: беседа с Андреа Дерлер
# 8   2022-05-26             Академия Аналитиков Авито: новый набор
# 9   2017-01-13                Минус одна система аналитики данных
# 10  2021-06-03  Искусственный интеллект и планирование закупок...
# 11  2022-10-24  Яндекс практикум, отзыв мазохиста. Курс Аналит...
# 12  2020-07-13  «Набор профессионала»: какие инструменты app-а...
# ...
